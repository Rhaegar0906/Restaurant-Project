# %%
from google.colab import drive
drive.mount('/content/gdrive')
import json
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(os.getcwd())
os.chdir("/content/gdrive/My Drive/Colab Notebooks (1)/yelp_dataset")
print(os.getcwd())
#os.listdir()
df = pd.read_csv("filtered_data.csv")
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content
# /content/gdrive/.shortcut-targets-by-id/1m5dVPIYDUmApGRmzUSFDadtixbOm-Lu2/Colab Notebooks/yelp_dataset
#                                    name             business_id  \
# 0                 b'St Honore Pastries'  MTSW4McQd7CbVtyjqoe9mw
# 1                     b'Sonic Drive-In'  CF33F8-E6oudUQ46HnavjQ
# 2                     b'Sonic Drive-In'  bBDDEgkFA1Otx9Lfe7BZUQ
# 3              b'Vietnamese Food Truck'  eEOYSgkmpB90uNA7lDOMRA
# 4                            b"Denny's"  il_Ro8jwPlHresjw9EGmBg
# ...                                 ...                     ...
# 34982           b'Bittercreek Alehouse'  w_4xUt-1AyY2ZwKtnjW0Xg
# 34983                           b'Wawa'  l9eLGG9ZKpLJzboZq-9LRQ
# 34984              b'Dutch Bros Coffee'  cM6V90ExQD6KMSU3rRB5ZA
# 34985  b'Adelita Taqueria & Restaurant'  WnT9NIzQgLlILjPT0kEcsQ
# 34986                   b'The Plum Pit'  2O2K6SXPWv56amqxCECd4w
#
#                    address             city state postal_code   latitude  \
# 0              935 Race St     Philadelphia    PA       19107  39.955505
# 1            615 S Main St     Ashland City    TN       37015  36.269593
# 2      2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 3                      NaN        Tampa Bay    FL       33602  27.955269
# 4             8901 US 31 S     Indianapolis    IN       46227  39.637133
# ...                    ...              ...   ...         ...        ...
# 34982         246 N 8th St            Boise    ID       83702  43.616590
# 34983      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 34984  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 34985        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 34986      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#         longitude                                         categories  stars  \
# 0      -75.155564  Restaurants, Food, Bubble Tea, Coffee & Tea, B...    4.0
# 1      -87.058943  Burgers, Fast Food, Sandwiches, Food, Ice Crea...    2.0
# 2      -86.768170  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...    1.5
# 3      -82.456320         Vietnamese, Food, Restaurants, Food Trucks    4.0
# 4      -86.127217  American (Traditional), Restaurants, Diners, B...    2.5
# ...           ...                                                ...    ...
# 34982 -116.202383  Bars, Gastropubs, Sandwiches, Nightlife, Resta...    4.5
# 34983  -75.310344  Restaurants, Sandwiches, Convenience Stores, C...    3.0
# 34984 -116.284689  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...    4.0
# 34985  -75.158665                               Restaurants, Mexican    4.5
# 34986  -75.427725  Restaurants, Comfort Food, Food, Food Trucks, ...    4.5
#
#        review_count                                         attributes  \
# 0                80  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1                 6  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 2                10  {'RestaurantsAttire': "'casual'", 'Restaurants...
# 3                10  {'Alcohol': "'none'", 'OutdoorSeating': 'None'...
# 4                28  {'RestaurantsReservations': 'False', 'Restaura...
# ...             ...                                                ...
# 34982           998  {'BikeParking': 'True', 'Alcohol': "u'full_bar...
# 34983            11  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 34984            33  {'WiFi': "'free'", 'RestaurantsGoodForGroups':...
# 34985            35  {'WheelchairAccessible': 'False', 'Restaurants...
# 34986            14  {'RestaurantsDelivery': 'False', 'BusinessAcce...
#
#                                                    hours  is_open  cluster_id  \
# 0      {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...        1          17
# 1      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...        1          21
# 2      {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...        1          21
# 3      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...        1          33
# 4      {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1           6
# ...                                                  ...      ...         ...
# 34982  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...        1           5
# 34983  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1          24
# 34984  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...        1           5
# 34985  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1          17
# 34986  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1          24
#
#        location
# 0            11
# 1             3
# 2             3
# 3            10
# 4             9
# ...         ...
# 34982         2
# 34983        11
# 34984         2
# 34985        11
# 34986        11
#
# [34987 rows x 16 columns]

# %%
#Creating a dictionary that has the counts of all the different categories found in the dataset
categories_list= []
categories_dict = {}
i = 0
for i in range(len(df)):
  new = df.categories.iloc[i]
  new = list(new.split(","))
  for n,s in enumerate(new):
    new[n] = s.strip()

  old = categories_list
  categories_list =  old + new

for c in range(len(categories_list)):
  categories_dict[categories_list[c]]= categories_list.count(categories_list[c])
#print(categories_dict)

#Sorting and take the top 20 (excluding food and restaurant)
sorted_categories = sorted(categories_dict.items(), key=lambda x:x[1], reverse= True)

new_cols = []
for i in range(2,23):
  new_cols.append(sorted_categories[i][0])
new_cols
# Out:
# ['Sandwiches',
#  'Nightlife',
#  'Bars',
#  'American (Traditional)',
#  'Fast Food',
#  'Pizza',
#  'Breakfast & Brunch',
#  'Burgers',
#  'American (New)',
#  'Mexican',
#  'Coffee & Tea',
#  'Italian',
#  'Seafood',
#  'Chicken Wings',
#  'Chinese',
#  'Event Planning & Services',
#  'Salad',
#  'Delis',
#  'Cafes',
#  'Caterers',
#  'Specialty Food']

# %%
def bincol(string):
  tf = [string in i for i in df.categories]
  df[string] = tf
for string in new_cols:
  bincol(string)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f225c23f1cd0> in <cell line: 4>()
#       2   tf = [string in i for i in df.categories]
#       3   df[string] = tf
# ----> 4 for string in new_cols:
#       5   bincol(string)
#       6 df
#
# NameError: name 'new_cols' is not defined

# %%
#Verification that columns were added
df.columns
# Out:
# Index(['name', 'business_id', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'categories', 'stars', 'review_count',
#        'attributes', 'hours', 'is_open', 'cluster_id', 'location',
#        'Sandwiches', 'Nightlife', 'Bars', 'American (Traditional)',
#        'Fast Food', 'Pizza', 'Breakfast & Brunch', 'Burgers', 'American (New)',
#        'Mexican', 'Coffee & Tea', 'Italian', 'Seafood', 'Chicken Wings',
#        'Chinese', 'Event Planning & Services', 'Salad', 'Delis', 'Cafes',
#        'Caterers', 'Specialty Food'],
#       dtype='object')

# %%
df.to_csv("ErintestCols.csv")
